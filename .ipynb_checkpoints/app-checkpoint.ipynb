# %%
import numpy as np
import pickle
import catboost
from catboost import CatBoostRegressor

# %%
from flask import Flask,request,render_template

# %%
app=Flask(__name__, template_folder='C:/Users/RAJA D/Downloads/main#/Player-Values-Predicition-In-IPL-main/template',static_folder='C:/Users/RAJA D/Downloads/main#/Player-Values-Predicition-In-IPL-main/static')
model=pickle.load(open('fifa.pkl','rb'))

# %%
@app.route('/')
def home():
    return render_template("index.html")

# %%
@app.route('/predict',methods=['POST'])
def predict():
    int_features = [float(x) for x in request.form.values()]
    final_features = [np.array(int_features)]
    prediction=model.predict(final_features)
    
    output = round(prediction[0],2)
    
    return render_template('predict.html',prediction_value='${}'.format(output)) 
    
if __name__=="__main__":
    app.run(debug=True,use_reloader=False)
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Running on http://127.0.0.1:5000 (Press CTRL+C to quit)
# 127.0.0.1 - - [15/Apr/2023 08:42:25] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Apr/2023 08:42:25] "GET /static/css/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Apr/2023 08:42:33] "POST /predict HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 2091, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 2076, in wsgi_app
#     response = self.handle_exception(e)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1519, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1517, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1503, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\RAJA D\AppData\Local\Temp\ipykernel_2868\3185337572.py", line 5, in predict
#     prediction=model.predict(final_features)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pycaret\internal\pipeline.py", line 310, in predict
#     X, _ = self._memory_full_transform(self, X, None, with_final=False)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\memory.py", line 594, in __call__
#     return self._cached_call(args, kwargs)[0]
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pycaret\internal\memory.py", line 398, in _cached_call
#     out, metadata = self.call(*args, **kwargs)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pycaret\internal\memory.py", line 309, in call
#     output = self.func(*args, **kwargs)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pycaret\internal\pipeline.py", line 108, in _full_transform
#     X, y = pipeline._memory_transform(transformer, X, y)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\memory.py", line 594, in __call__
#     return self._cached_call(args, kwargs)[0]
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pycaret\internal\memory.py", line 398, in _cached_call
#     out, metadata = self.call(*args, **kwargs)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pycaret\internal\memory.py", line 309, in call
#     output = self.func(*args, **kwargs)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pycaret\internal\pipeline.py", line 77, in _transform_one
#     output = transformer.transform(*args)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pycaret\internal\preprocess\transformers.py", line 238, in transform
#     args.append(X[self._include])
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py", line 3813, in __getitem__
#     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py", line 6070, in _get_indexer_strict
#     self._raise_if_missing(keyarr, indexer, axis_name)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py", line 6130, in _raise_if_missing
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['RAA', 'Wins', 'EFscore', 'Salary'], dtype='object')] are in the [columns]"
# 127.0.0.1 - - [15/Apr/2023 08:42:33] "GET /predict?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Apr/2023 08:42:33] "GET /predict?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Apr/2023 08:42:33] "GET /predict?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Apr/2023 08:46:25] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Apr/2023 08:46:29] "GET /static/css/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Apr/2023 08:46:30] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [15/Apr/2023 08:46:37] "POST /predict HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 2091, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 2076, in wsgi_app
#     response = self.handle_exception(e)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1519, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1517, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1503, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\RAJA D\AppData\Local\Temp\ipykernel_2868\3185337572.py", line 5, in predict
#     prediction=model.predict(final_features)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pycaret\internal\pipeline.py", line 310, in predict
#     X, _ = self._memory_full_transform(self, X, None, with_final=False)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\memory.py", line 594, in __call__
#     return self._cached_call(args, kwargs)[0]
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pycaret\internal\memory.py", line 398, in _cached_call
#     out, metadata = self.call(*args, **kwargs)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pycaret\internal\memory.py", line 309, in call
#     output = self.func(*args, **kwargs)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pycaret\internal\pipeline.py", line 108, in _full_transform
#     X, y = pipeline._memory_transform(transformer, X, y)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\memory.py", line 594, in __call__
#     return self._cached_call(args, kwargs)[0]
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pycaret\internal\memory.py", line 398, in _cached_call
#     out, metadata = self.call(*args, **kwargs)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pycaret\internal\memory.py", line 309, in call
#     output = self.func(*args, **kwargs)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pycaret\internal\pipeline.py", line 77, in _transform_one
#     output = transformer.transform(*args)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pycaret\internal\preprocess\transformers.py", line 238, in transform
#     args.append(X[self._include])
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py", line 3813, in __getitem__
#     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py", line 6070, in _get_indexer_strict
#     self._raise_if_missing(keyarr, indexer, axis_name)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py", line 6130, in _raise_if_missing
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['RAA', 'Wins', 'EFscore', 'Salary'], dtype='object')] are in the [columns]"
# 127.0.0.1 - - [15/Apr/2023 08:46:37] "GET /predict?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Apr/2023 08:46:37] "GET /predict?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Apr/2023 08:46:37] "GET /predict?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Apr/2023 08:48:48] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Apr/2023 08:48:48] "GET /static/css/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Apr/2023 08:49:01] "POST /predict HTTP/1.1" 500 -
# Traceback (most recent call last):
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 2091, in __call__
#     return self.wsgi_app(environ, start_response)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 2076, in wsgi_app
#     response = self.handle_exception(e)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1519, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1517, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1503, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\RAJA D\AppData\Local\Temp\ipykernel_2868\3185337572.py", line 5, in predict
#     prediction=model.predict(final_features)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pycaret\internal\pipeline.py", line 310, in predict
#     X, _ = self._memory_full_transform(self, X, None, with_final=False)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\memory.py", line 594, in __call__
#     return self._cached_call(args, kwargs)[0]
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pycaret\internal\memory.py", line 398, in _cached_call
#     out, metadata = self.call(*args, **kwargs)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pycaret\internal\memory.py", line 309, in call
#     output = self.func(*args, **kwargs)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pycaret\internal\pipeline.py", line 108, in _full_transform
#     X, y = pipeline._memory_transform(transformer, X, y)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\memory.py", line 594, in __call__
#     return self._cached_call(args, kwargs)[0]
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pycaret\internal\memory.py", line 398, in _cached_call
#     out, metadata = self.call(*args, **kwargs)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pycaret\internal\memory.py", line 309, in call
#     output = self.func(*args, **kwargs)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pycaret\internal\pipeline.py", line 77, in _transform_one
#     output = transformer.transform(*args)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pycaret\internal\preprocess\transformers.py", line 238, in transform
#     args.append(X[self._include])
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py", line 3813, in __getitem__
#     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py", line 6070, in _get_indexer_strict
#     self._raise_if_missing(keyarr, indexer, axis_name)
#   File "C:\Users\RAJA D\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py", line 6130, in _raise_if_missing
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['RAA', 'Wins', 'EFscore', 'Salary'], dtype='object')] are in the [columns]"
# 127.0.0.1 - - [15/Apr/2023 08:49:01] "GET /predict?__debugger__=yes&cmd=resource&f=style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Apr/2023 08:49:01] "GET /predict?__debugger__=yes&cmd=resource&f=debugger.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Apr/2023 08:49:01] "GET /predict?__debugger__=yes&cmd=resource&f=console.png HTTP/1.1" 304 -
